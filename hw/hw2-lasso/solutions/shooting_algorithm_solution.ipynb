# %% [markdown]
# # Q3.1 Experiments with the shooting algorithm

# %%
from lasso_solutions import LassoRegression, do_grid_search_lasso, do_grid_search_homotopy
from release.code.setup_problem import load_problem
from release.code.ridge_regression import plot_prediction_functions, do_grid_search_ridge, RidgeRegression, compare_parameter_vectors

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Q3.1.2
# Compare Lasso solution with cyclic coordinates descent versus randomized coordinates descent;
#
# Compare Lasso solution attained for starting from 0 versus starting from ridge regression solution (suggested by Murphy).

# %%
# Load dataset
lasso_data_fname = "release/code/lasso_data.pickle"
x_train, y_train, x_val, y_val, target_fn, coefs_true, featurize = load_problem(lasso_data_fname)
X_train = featurize(x_train)
X_val = featurize(x_val)

pred_fns = []

# Target function
x = np.sort(np.concatenate([np.arange(0,1,.001), x_train]))
X = featurize(x)
name = "Target Parameter Values (i.e. Bayes Optimal)"
pred_fns.append({"name":name, "coefs":coefs_true, "preds": target_fn(x) })
coef_init = np.zeros(X.shape[1])

# Lasso with cyclic coordinates descent
l1_reg = 0.08 
name = "l1_reg = 0.08 --- Lasso with cyclic coordinates descent"
print(name)
print(' -- ', end = '')
lasso_regression_estimator = LassoRegression(l1_reg=l1_reg)
lasso_regression_estimator.fit(X_train, y_train, max_epochs = 2000, coef_init=coef_init)
score = lasso_regression_estimator.score(X_val, y_val)
print(' -- Average validation loss: '+str(score))


pred_fns.append({"name":name,
                 "coefs":lasso_regression_estimator.w_,
                 "preds": lasso_regression_estimator.predict(X) })

# Lasso with randomized coordinates descent
name = "l1_reg = 0.08 --- Lasso with randomized coordinates descent"
print(name)
print(' -- ', end = '')
lasso_regression_estimator_randomized = LassoRegression(l1_reg=l1_reg, randomized=True)
lasso_regression_estimator_randomized.fit(X_train, y_train, max_epochs = 2000, coef_init=coef_init)

score = lasso_regression_estimator_randomized.score(X_val, y_val)
print(' -- Average validation loss: '+str(score))


pred_fns.append({"name":name,
                 "coefs":lasso_regression_estimator_randomized.w_,
                 "preds": lasso_regression_estimator_randomized.predict(X) })



# Lasso starting at ridge regression solution
name = "l1_reg = 0.08 --- Lasso starting at ridge regression solution"
print(name)
print(' -- ', end = '')
lasso_regression_estimator_murphy = LassoRegression(l1_reg=l1_reg)
lasso_regression_estimator_murphy.fit(X_train, y_train)

score = lasso_regression_estimator_murphy.score(X_val, y_val)
print(' -- Average validation loss: '+str(score))

pred_fns.append({"name":name,
                 "coefs":lasso_regression_estimator_murphy.w_,
                 "preds": lasso_regression_estimator_murphy.predict(X) })

# Lasso with cyclic coordinates descent
l1_reg = 1
name = "l1_reg = 1 --- Lasso with cyclic coordinates descent"
print(name)
print(' -- ', end = '')
lasso_regression_estimator = LassoRegression(l1_reg=l1_reg)
lasso_regression_estimator.fit(X_train, y_train, max_epochs = 2000, coef_init=coef_init)
score = lasso_regression_estimator.score(X_val, y_val)
print(' -- Average validation loss: '+str(score))


pred_fns.append({"name":name,
                 "coefs":lasso_regression_estimator.w_,
                 "preds": lasso_regression_estimator.predict(X) })

# Lasso with randomized coordinates descent
name = "l1_reg = 1 --- Lasso with randomized coordinates descent"
print(name)
print(' -- ', end = '')
lasso_regression_estimator_randomized = LassoRegression(l1_reg=l1_reg, randomized=True)
lasso_regression_estimator_randomized.fit(X_train, y_train, max_epochs = 2000, coef_init=coef_init)

score = lasso_regression_estimator_randomized.score(X_val, y_val)
print(' -- Average validation loss: '+str(score))


pred_fns.append({"name":name,
                 "coefs":lasso_regression_estimator_randomized.w_,
                 "preds": lasso_regression_estimator_randomized.predict(X) })



# Lasso starting at ridge regression solution
name = "l1_reg = 1 --- Lasso starting at ridge regression solution"
print(name)
print(' -- ', end = '')
lasso_regression_estimator_murphy = LassoRegression(l1_reg=l1_reg)
lasso_regression_estimator_murphy.fit(X_train, y_train)

score = lasso_regression_estimator_murphy.score(X_val, y_val)
print(' -- Average validation loss: '+str(score))

pred_fns.append({"name":name,
                 "coefs":lasso_regression_estimator_murphy.w_,
                 "preds": lasso_regression_estimator_murphy.predict(X) })

# Lasso with cyclic coordinates descent
l1_reg = 10
name = "l1_reg = 10 --- Lasso with cyclic coordinates descent"
print(name)
print(' -- ', end = '')
lasso_regression_estimator = LassoRegression(l1_reg=l1_reg)
lasso_regression_estimator.fit(X_train, y_train, max_epochs = 2000, coef_init=coef_init)
score = lasso_regression_estimator.score(X_val, y_val)
print(' -- Average validation loss: '+str(score))


pred_fns.append({"name":name,
                 "coefs":lasso_regression_estimator.w_,
                 "preds": lasso_regression_estimator.predict(X) })

# Lasso with randomized coordinates descent
name = "l1_reg = 10 --- Lasso with randomized coordinates descent"
print(name)
print(' -- ', end = '')
lasso_regression_estimator_randomized = LassoRegression(l1_reg=l1_reg, randomized=True)
lasso_regression_estimator_randomized.fit(X_train, y_train, max_epochs = 2000, coef_init=coef_init)

score = lasso_regression_estimator_randomized.score(X_val, y_val)
print(' -- Average validation loss: '+str(score))


pred_fns.append({"name":name,
                 "coefs":lasso_regression_estimator_randomized.w_,
                 "preds": lasso_regression_estimator_randomized.predict(X) })



# Lasso starting at ridge regression solution
name = "l1_reg = 10 --- Lasso starting at ridge regression solution"
print(name)
print(' -- ', end = '')
lasso_regression_estimator_murphy = LassoRegression(l1_reg=l1_reg)
lasso_regression_estimator_murphy.fit(X_train, y_train)

score = lasso_regression_estimator_murphy.score(X_val, y_val)
print(' -- Average validation loss: '+str(score))

pred_fns.append({"name":name,
                 "coefs":lasso_regression_estimator_murphy.w_,
                 "preds": lasso_regression_estimator_murphy.predict(X) })
# Out:
# l1_reg = 0.08 --- Lasso with cyclic coordinates descent
#  -- Ran for 1151 epochs.Lowest loss: 3.330833267317918
#  -- Average validation loss: 0.20973717943447476
# l1_reg = 0.08 --- Lasso with randomized coordinates descent
#  -- Ran for 2000 epochs.Lowest loss: 3.3312803565729485
#  -- Average validation loss: 0.16354978379335142
# l1_reg = 0.08 --- Lasso starting at ridge regression solution
#  -- Ran for 833 epochs.Lowest loss: 3.3308331013845542
#  -- Average validation loss: 0.1638832520965038
# l1_reg = 1 --- Lasso with cyclic coordinates descent
#  -- Ran for 824 epochs.Lowest loss: 16.19773797187303
#  -- Average validation loss: 0.16781937496866406
# l1_reg = 1 --- Lasso with randomized coordinates descent
#  -- Ran for 479 epochs.Lowest loss: 16.19773812049297
#  -- Average validation loss: 0.12500758058714267
# l1_reg = 1 --- Lasso starting at ridge regression solution
#  -- Ran for 730 epochs.Lowest loss: 16.19773806144752
#  -- Average validation loss: 0.1264395698710981
# l1_reg = 10 --- Lasso with cyclic coordinates descent
#  -- Ran for 742 epochs.Lowest loss: 56.81897663333592
#  -- Average validation loss: 0.20768110867976777
# l1_reg = 10 --- Lasso with randomized coordinates descent
#  -- Ran for 674 epochs.Lowest loss: 56.81897665032854
#  -- Average validation loss: 0.19264802611336967
# l1_reg = 10 --- Lasso starting at ridge regression solution
#  -- Ran for 641 epochs.Lowest loss: 56.818976595568785
#  -- Average validation loss: 0.1951053457142927

# %% [markdown]
# ## Q3.1.3
# Parameter tuning;
#
# Lasso and ridge solution compare.

# %%
grid, results = do_grid_search_lasso(X_train, y_train, X_val, y_val)
# Out:
# Ran for 6 epochs.Lowest loss: 0.6789099908363103
# Ran for 231 epochs.Lowest loss: 0.7123822291805979
# Ran for 571 epochs.Lowest loss: 1.0422432500360441
# Ran for 830 epochs.Lowest loss: 3.9049738772510736
# Ran for 730 epochs.Lowest loss: 16.19773806144752
# Ran for 641 epochs.Lowest loss: 56.818976595568785
# Ran for 693 epochs.Lowest loss: 221.86396593209417
# Ran for 903 epochs.Lowest loss: 7.4114981304745005
# Ran for 792 epochs.Lowest loss: 11.403997553589027
# Ran for 796 epochs.Lowest loss: 14.184644092885888
# Ran for 730 epochs.Lowest loss: 16.19773806144752
# Ran for 719 epochs.Lowest loss: 17.87920585225224
# Ran for 704 epochs.Lowest loss: 19.508009470245895
# Ran for 683 epochs.Lowest loss: 21.08967426468346
# Ran for 644 epochs.Lowest loss: 22.624200220734316
# Ran for 619 epochs.Lowest loss: 24.112518958678095
# Ran for 590 epochs.Lowest loss: 25.55931096611679
# Ran for 519 epochs.Lowest loss: 26.96622303354843
# Ran for 410 epochs.Lowest loss: 28.334255123840833
# Ran for 512 epochs.Lowest loss: 29.663603749453138
# Ran for 794 epochs.Lowest loss: 12.033076340630199
# Ran for 796 epochs.Lowest loss: 12.623058384344432
# Ran for 798 epochs.Lowest loss: 13.177019690597689
# Ran for 799 epochs.Lowest loss: 13.69718754680854
# Ran for 796 epochs.Lowest loss: 14.18464409288589
# Ran for 792 epochs.Lowest loss: 14.640976611551292
# Ran for 789 epochs.Lowest loss: 15.067248724871796
# Ran for 786 epochs.Lowest loss: 15.465087762931873
# Ran for 795 epochs.Lowest loss: 14.370877299017366
# Ran for 793 epochs.Lowest loss: 14.55217516190977
# Ran for 792 epochs.Lowest loss: 14.728547342612096

# %%
results
# Out:
#     param_l1_reg  mean_test_score  mean_train_score
# 0         0.0001         0.172578          0.006752
# 1         0.0010         0.172471          0.006752
# 2         0.0100         0.171410          0.006806
# 3         0.1000         0.162105          0.011143
# 7         0.2500         0.148975          0.024710
# 8         0.5000         0.136842          0.048919
# 20        0.5500         0.135228          0.053337
# 21        0.6000         0.133866          0.057684
# 22        0.6500         0.132625          0.061976
# 23        0.7000         0.131377          0.066474
# 9         0.7500         0.130243          0.071085
# 24        0.7500         0.130243          0.071085
# 28        0.7700         0.129791          0.072967
# 29        0.7900         0.129317          0.074888
# 25        0.8000         0.129087          0.075867
# 30        0.8100         0.128870          0.076851
# 26        0.8500         0.128037          0.080639
# 27        0.9000         0.127215          0.085560
# 10        1.0000         0.126440          0.091950
# 4         1.0000         0.126440          0.091950
# 11        1.2500         0.125946          0.096174
# 12        1.5000         0.126193          0.098766
# 13        1.7500         0.126889          0.101830
# 14        2.0000         0.127986          0.105365
# 15        2.2500         0.128950          0.109074
# 16        2.5000         0.129982          0.112944
# 17        2.7500         0.131494          0.117044
# 18        3.0000         0.133294          0.121506
# 19        3.2500         0.135396          0.126300
# 5        10.0000         0.195105          0.226209
# 6       100.0000         0.845093          0.883771

# %%
# Plot validation performance vs regularization parameter
fig, ax = plt.subplots()
ax.semilogx(results["param_l1_reg"], results["mean_test_score"])
ax.grid()
ax.set_title("Validation Performance vs L1 Regularization")
ax.set_xlabel("L1-Penalty Regularization Parameter")
ax.set_ylabel("Mean Squared Error")
plt.show()

# %%
pred_fns_ = []

# Get optimal solution from ridge regression
ridge_grid, ridge_results = do_grid_search_ridge(X_train, y_train, X_val, y_val)
l2_reg = ridge_grid.best_params_['l2reg']
ridge_regression_estimator = RidgeRegression(l2reg=l2_reg)
ridge_regression_estimator.fit(X_train, y_train)
name = "Ridge with L2Reg="+str(l2_reg)
pred_fns_.append({"name":name,
                 "coefs":ridge_regression_estimator.w_,
                 "preds": ridge_regression_estimator.predict(X) })

# Get optimal solution from Lasso regression
l1_reg = grid.best_params_['l1_reg']
lasso_regression_estimator = LassoRegression(l1_reg=l1_reg)
lasso_regression_estimator.fit(X_train, y_train)
name = "Lasso with L1Reg="+str(l1_reg)
pred_fns_.append({"name":name,
                 "coefs":lasso_regression_estimator.w_,
                 "preds": lasso_regression_estimator.predict(X) })

# Compare parameters from Lasso regression versus ridge regression
compare_parameter_vectors(pred_fns_)
# Out:
# Ran for 719 epochs.Lowest loss: 17.879205852252245

# %%
pred_fns_.append({"name":"Target Parameter Values (i.e. Bayes Optimal)", "coefs":coefs_true, "preds": target_fn(x) })
f = plot_prediction_functions(x, pred_fns_, x_train, y_train)
plt.show()

# %% [markdown]
# ## Q3.1.4
# Implement homotopy method.

# %%
lasso_reg_path_estimator = do_grid_search_homotopy(X_train, y_train, X_val, y_val)
scores = lasso_reg_path_estimator.score(X_val, y_val)
# Out:
# Ran for 1 epochs. Lowest loss: 359.66740028131966
# Ran for 594 epochs. Lowest loss: 348.52108633392805
# Ran for 578 epochs. Lowest loss: 323.5371648237496
# Ran for 705 epochs. Lowest loss: 293.22926472360444
# Ran for 671 epochs. Lowest loss: 262.2363733206085
# Ran for 136 epochs. Lowest loss: 231.30364679470637
# Ran for 132 epochs. Lowest loss: 202.0174853438218
# Ran for 127 epochs. Lowest loss: 175.68296871183844
# Ran for 303 epochs. Lowest loss: 152.73952217465137
# Ran for 319 epochs. Lowest loss: 133.12872392009874
# Ran for 300 epochs. Lowest loss: 116.62091752850151
# Ran for 280 epochs. Lowest loss: 102.89040503458665
# Ran for 319 epochs. Lowest loss: 91.40127958050607
# Ran for 351 epochs. Lowest loss: 80.59513427785576
# Ran for 332 epochs. Lowest loss: 70.65131127999412
# Ran for 313 epochs. Lowest loss: 61.83896897477649
# Ran for 334 epochs. Lowest loss: 54.08107969936127
# Ran for 320 epochs. Lowest loss: 47.3266690315174
# Ran for 301 epochs. Lowest loss: 41.56428576679453
# Ran for 614 epochs. Lowest loss: 36.69712945939425
# Ran for 723 epochs. Lowest loss: 32.32317412430601
# Ran for 700 epochs. Lowest loss: 28.434762283530574
# Ran for 669 epochs. Lowest loss: 25.071530452726044
# Ran for 643 epochs. Lowest loss: 22.211091350772826
# Ran for 657 epochs. Lowest loss: 19.799697382372205
# Ran for 630 epochs. Lowest loss: 17.789509032870527
# Ran for 603 epochs. Lowest loss: 16.121413497283267
# Ran for 604 epochs. Lowest loss: 14.563979468681882
# Ran for 575 epochs. Lowest loss: 12.993126809546265
# Ran for 543 epochs. Lowest loss: 11.487542271474762

# %%
scores_ = pd.DataFrame(scores)
scores_
# Out:
#        reg_val     score
# 0   327.282832  3.576553
# 1   261.826266  2.584477
# 2   209.461013  1.953811
# 3   167.568810  1.540006
# 4   134.055048  1.230752
# 5   107.244038  0.925121
# 6    85.795231  0.729477
# 7    68.636185  0.604231
# 8    54.908948  0.522022
# 9    43.927158  0.466785
# 10   35.141727  0.431562
# 11   28.113381  0.409120
# 12   22.490705  0.360808
# 13   17.992564  0.290754
# 14   14.394051  0.249029
# 15   11.515241  0.222491
# 16    9.212193  0.201319
# 17    7.369754  0.191508
# 18    5.895803  0.187244
# 19    4.716643  0.182376
# 20    3.773314  0.174341
# 21    3.018651  0.170569
# 22    2.414921  0.168641
# 23    1.931937  0.167468
# 24    1.545549  0.167141
# 25    1.236440  0.167414
# 26    0.989152  0.167828
# 27    0.791321  0.169226
# 28    0.633057  0.171699
# 29    0.506446  0.174975

# %%
fig, ax = plt.subplots()
ax.semilogx(scores_["reg_val"], scores_["score"])
ax.grid()
ax.set_title("Validation Performance vs L1 Regularization with homotopy method")
ax.set_xlabel("L1-Penalty Regularization Parameter")
ax.set_ylabel("Mean Squared Error")
plt.show()

# %%
# zoomming in around the minimum 
fig, ax = plt.subplots()
ax.semilogx(scores_["reg_val"][15:], scores_["score"][15:])
ax.grid()
ax.set_title("Validation Performance vs L1 Regularization with homotopy method")
ax.set_xlabel("L1-Penalty Regularization Parameter")
ax.set_ylabel("Mean Squared Error")
plt.show()
